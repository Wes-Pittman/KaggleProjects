# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")
# Out:
# Setup Complete

# %%
# Construct the file path for Country
countryData = 'C:\\Users\\pittm\\Programming\\Kaggle\\FWP-CountryData.xlsx'
# Construct the file path for Players
playerData = 'C:\\Users\\pittm\\Programming\\Kaggle\\FWP-PlayerData.xlsx'

# Read the file into a variable fifa_data
fifa_countryData = pd.read_excel(countryData)
fifa_playerData = pd.read_excel(playerData)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8980/313989018.py in <module>
#       6 # Read the file into a variable fifa_data
#       7 fifa_countryData = pd.read_excel(countryData)
# ----> 8 fifa_playerData = pd.read_excel(playerData)
#
# c:\Users\pittm\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
# Print the first 5 rows of the data
fifa_data.head()
fifa_data.tail()
# Out:
#      Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Playing Time Unnamed: 5  \
# 0         Squad       # Pl        Age       Poss           MP     Starts
# 1  ar Argentina         24       27.5       57.4            7         77
# 2  au Australia         20       27.8       37.8            4         44
# 3    be Belgium         20       29.7         57            3         33
# 4     br Brazil         26       27.6       56.2            5         55
#
#   Unnamed: 6 Unnamed: 7 Performance Unnamed: 9  ... Unnamed: 19 Expected  \
# 0        Min        90s         Gls        Ast  ...      G+A-PK       xG
# 1        690        7.7          15          8  ...        2.48     15.1
# 2        360          4           3          3  ...         1.5      2.3
# 3        270          3           1          1  ...        0.67      4.7
# 4        480        5.3           8          6  ...        2.44       12
#
#   Unnamed: 21 Unnamed: 22 Unnamed: 23 Per 90 Minutes.1 Unnamed: 25  \
# ...
